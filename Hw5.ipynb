# %%
# %matplotlib inline
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import scipy
from scipy import stats
import pandas as pd
import math
import statistics
import h5py
import pickle
import random
from random import randrange

# %% [markdown]
# # Problem 1
#
# ## Create a normal distrobution with 1mil points for throwing

# %%
bkgd = stats.norm.rvs(loc = 0, scale = 3, size = 1000000)
plt.hist(bkgd, density = True)

signal = stats.uniform.rvs(0,20,1000000)
plt.hist(r, density = True)
plt.show()

# %% [markdown]
# ## Problem 1b
#
# ### Select a true injected signal and plot P(d|s). (Use a stair style plot). Label your plot and clearly explain what you are plotting and how to interpret it. [Hint: this was also shown in class.]

# %%
data = bkgd + signal

signaledges = np.linspace(0,20,40)
dataedges = np.linspace(-7,27,68)

Psd, temp, temp2= np.histogram2d(data,signal, bins=[dataedges,signaledges], density=True)

fig, ax = plt.subplots(nrows = 1, ncols =2, figsize = (8,4))

datacenters = (dataedges[:-1] + dataedges[1:]) / 2
signalcenters = (signaledges[:-1] + signaledges[1:]) / 2
ax[0].pcolormesh(datacenters,signalcenters,Psd.T)
ax[0].set_ylabel('True signal, $P(s|d)$', fontsize = 24)
ax[0].set_xlabel('Observed data, $P(d|s)$', fontsize = 24)
ax[0].set_title('2D Histogram')

ax[0].axhline(y=10, color='r', linestyle='--')


i = Psd[:,20]
ax[1].step(datacenters, i)
ax[1].set_yscale('log')
ax[1].set_title('Slice at True Signal = 10.25')
ax[1].set_xlabel('Observed Signal, P(d|s)')

plt.show()
# Out:
# <ipython-input-274-beb7fd6791b1>:12: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   ax[0].pcolormesh(datacenters,signalcenters,Psd.T)

# %% [markdown]
# #### what is being plotted is the cross-sectional view of the 2D histogram at the point of the red line. This indicates the value of the observed data at the true signal value of interest.

# %% [markdown]
# # Problem 1c
#
# ### Select an observed data value and plot P(s|d)
# ### (Use a stair style plot). Label your plot and clearly explain what you are plotting and how to interpret it.

# %%
data = bkgd + signal

signaledges = np.linspace(0,20,40)
dataedges = np.linspace(-7,27,68)

Psd, temp, temp2= np.histogram2d(data,signal, bins=[dataedges,signaledges], density=True)

fig, ax = plt.subplots(nrows = 1, ncols =2, figsize = (8,4))

datacenters = (dataedges[:-1] + dataedges[1:]) / 2
signalcenters = (signaledges[:-1] + signaledges[1:]) / 2
ax[0].pcolormesh(datacenters,signalcenters,Psd.T)
ax[0].set_ylabel('True signal, $P(s|d)$', fontsize = 24)
ax[0].set_xlabel('Observed data, $P(d|s)$', fontsize = 24)
ax[0].set_title('2D Histogram')

ax[0].axvline(x=10, color='r', linestyle='--')


ax[1].step(signalcenters,Psd[34,:])
ax[1].set_yscale('log')
ax[1].set_title('Slice at Observed Signal = 10.5')
ax[1].set_xlabel('True Signal, P(s|d)')

plt.show()
# Out:
# <ipython-input-275-03f4818a6191>:12: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   ax[0].pcolormesh(datacenters,signalcenters,Psd.T)

# %% [markdown]
# #### What is being plotted is the cross-sectional view of the 2D histogram at the point of the red line. This indicates the value of the true signal at the observed value of interest.

# %% [markdown]
# # Problem 2
#
# ### Now repeat the above, but with a background with non-zero mean. The easiest way would be to still have Guassian distribution but with a non-zero mean. [Hint: move it by at least a couple of σ]. Reproduce the graphs above. Lastly overplot the P(d|s) and P(s|d) plots. Why are they not centered on the same value? Explain carefully.

# %%
bkgd = stats.norm.rvs(loc = 6, scale = 3, size = 1000000)
#plt.hist(bkgd, density = True)

signal = stats.uniform.rvs(0,20,1000000)
#plt.hist(r, density = True)
#plt.show()
data = bkgd + signal

data = bkgd + signal

signaledges = np.linspace(0,20,40)
dataedges = np.linspace(-7,27,68)

Psd, temp, temp2= np.histogram2d(data,signal, bins=[dataedges,signaledges], density=True)

fig, ax = plt.subplots(nrows = 1, ncols =2, figsize = (8,4))

datacenters = (dataedges[:-1] + dataedges[1:]) / 2
signalcenters = (signaledges[:-1] + signaledges[1:]) / 2
ax[0].pcolormesh(datacenters,signalcenters,Psd.T)
ax[0].set_ylabel('True signal, $P(s|d)$', fontsize = 24)
ax[0].set_xlabel('Observed data, $P(d|s)$', fontsize = 24)
ax[0].set_title('2D Histogram')

ax[0].axhline(y=10, color='r', linestyle='--')


i = Psd[:,20]
ax[1].step(datacenters, i)
ax[1].set_yscale('log')
ax[1].set_title('Slice at True Signal = 10.25')
ax[1].set_xlabel('Observed Signal, P(d|s)')

plt.show()
# Out:
# <ipython-input-276-f8904eb81ed0>:20: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   ax[0].pcolormesh(datacenters,signalcenters,Psd.T)

# %%
bkgd = stats.norm.rvs(loc = 6, scale = 3, size = 1000000)
#plt.hist(bkgd, density = True)

signal = stats.uniform.rvs(0,20,1000000)
#plt.hist(r, density = True)
#plt.show()
data = bkgd + signal

signaledges = np.linspace(0,20,40)
dataedges = np.linspace(-7,27,68)

Psd, temp, temp2= np.histogram2d(data,signal, bins=[dataedges,signaledges], density=True)

fig, ax = plt.subplots(nrows = 1, ncols =2, figsize = (8,4))

datacenters = (dataedges[:-1] + dataedges[1:]) / 2
signalcenters = (signaledges[:-1] + signaledges[1:]) / 2
ax[0].pcolormesh(datacenters,signalcenters,Psd.T)
ax[0].set_ylabel('True signal, $P(s|d)$', fontsize = 24)
ax[0].set_xlabel('Observed data, $P(d|s)$', fontsize = 24)
ax[0].set_title('2D Histogram')

ax[0].axvline(x=10, color='r', linestyle='--')


ax[1].step(signalcenters,Psd[34,:])
ax[1].set_yscale('log')
ax[1].set_title('Slice at Observed Signal = 10.5')
ax[1].set_xlabel('True Signal, P(s|d)')
ax[1].set_xlim(-1,20)

plt.show()
# Out:
# <ipython-input-277-8f953e238326>:18: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   ax[0].pcolormesh(datacenters,signalcenters,Psd.T)

# %% [markdown]
# ### Why are they not centered on the same value? Explain carefully.
#
# #### The plots are not the same due to a shifting of the 2d Histogram from a change in background distrobution by a sizeable change in mean value. The sum of our injected signal and the now non-zero background was different due adding different values.

# %%
i = Psd[:,20]
plt.step(datacenters, i)
plt.step(signalcenters,Psd[34,:])
plt.yscale('log')
plt.title('P(s|d) P(d|s) overplot')
plt.xlabel('Signal Value')
plt.show()

# %% [markdown]
# #### The plots intersect at the proved value with means a distance equal to the standard deviation from that point.
